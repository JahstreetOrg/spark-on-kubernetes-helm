// %%
%%configure -f
{
    "name": "_template_scala",
    "proxyUser": "jupyter_user",
    "driverMemory": "2G",
    "executorMemory": "2G",
    "numExecutors": 2,
    "jars": [
    ],
    "conf": {
        "spark.kubernetes.allocation.batch.size": 10
    }
}

// %%
%%html
<style>.container { width:90% !important; }</style>

// %%
spark

// %%
1 + 1

// %%
import spark.implicits._
val df = Seq(1,2,3,4,5,6,7,8,9).toDF.repartition(5)

// %%
df.count

// %%
df.show
